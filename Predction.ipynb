-- %%
nn = require 'nn'
model=torch.load('model.net')

-- %%
original=image.load('a.jpg',3,'byte')
scaled=image.scale(original,20,20):double()
itorch.image(image.scale(original,200,200))
-- Out:
-- Console does not support images

-- %%
prediction = model:forward(scaled)
confidences, indices = torch.sort(prediction, true)  
alpha=48
beta=65
gamma=indices[1]
if gamma < 11 then
    print(string.char(alpha+gamma-1))
else
    beta=beta+gamma-11
    print(string.char(beta))
end
-- Out:
-- K

-- %%
for i=1,6 do   
    filteroutput = model.modules[i].output
    img = torch.Tensor(6,50,50)
    for j=1,6 do
        img[j] = image.scale(filteroutput[j],50,50)
    end
    itorch.image(img)
end
-- Out:
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
